# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn
import tensorflow as tf
model = tf.keras.models.load_model('C:/Users/yanzh/Interpolation/Dissolved Oxygen/saved_model/my_modelBB38_DO')

# Check its architecture
model.summary()

df = pd.read_csv("C:/Users/yanzh/Desktop/DO_data/BB38.csv")
time = df['time'].values
DO = df['dissolved oxygen'].values
df

#Transform the normalized scale to real scale
DO_min = 2.616666667
DO_max = 10.22333333
time_min = 34710   
time_max = 44356.35417   

newtimepoints_scaled = np.linspace(time[0] - (time[1] - time[0]),time[-1], 10000)
y_predicted_scaled = model.predict(newtimepoints_scaled)

newtimepoints = newtimepoints_scaled*(time_max - time_min) + time_min
y_predicted = y_predicted_scaled*(DO_max - DO_min) + DO_min

# Display the result
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)
plt.scatter(time*(time_max - time_min) + time_min, DO*(DO_max - DO_min) + DO_min, label='Original Data')
plt.scatter(newtimepoints, y_predicted, c = 'red', s = 1, label = 'Interpolated Data')
plt.xlabel('Time')
plt.ylabel('Dissolved Oxygen')
plt.legend()
plt.show()

model.evaluate(newtimepoints_scaled, y_predicted_scaled, batch_size=32)
print(model.metrics_names)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                128
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                544
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,459
# Trainable params: 5,459
# Non-trainable params: 0
# _________________________________________________________________
# 313/313 [==============================] - 0s 327us/step - loss: 4.3707e-16
# ['loss']

# %%
interpolation = model.predict([0.375166432
,0.95569476
,0.958804734
,0.962018373
])
interpolation
# Out:
# array([[0.44600633],
#        [0.4985379 ],
#        [0.4996859 ],
#        [0.5008722 ]], dtype=float32)
